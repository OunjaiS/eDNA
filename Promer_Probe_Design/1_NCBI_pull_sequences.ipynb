# %%
from Bio import Entrez, SeqIO
import time
import csv
import re
import os
from collections import defaultdict

# ตั้งค่าอีเมลและ API Key
Entrez.email = "ounjai.sa@gmail.com"
Entrez.api_key = "573465c00e14b785945465d1dbe40c32ad08"

# =============================================================================
# การตั้งค่าการดึงข้อมูล
# =============================================================================

# ตั้งค่าไฟล์อินพุตและเอาต์พุต
FISH_LIST_FILE = "/Users/sarawut/Desktop/oneclick/thai_fish_database.txt"
OUTPUT_FASTA = "/Users/sarawut/Desktop/oneclick/thai_fish_sequences_ON_COI.fasta"
OUTPUT_METADATA = "/Users/sarawut/Desktop/oneclick/thai_fish_metadata_ON_COI.csv"

# ตั้งค่าสปีชีส์หลัก (จะดึงข้อมูลทั้งหมดที่หาได้)
TARGET_SPECIES = [
    "oreochromis niloticus",
    # เพิ่มสปีชีส์หลักอื่นๆ ได้ที่นี่
]

# ตั้งค่าจำนวนซีเควนซ์สำหรับสปีชีส์เปรียบเทียบ
COMPARISON_SEQUENCES_PER_SPECIES = 3  # จำนวนซีเควนซ์ต่อสปีชีส์สำหรับเปรียบเทียบ

# ตั้งค่าประเภทของซีเควนซ์ที่ต้องการ
SEARCH_TERMS = [
    "COI",
    "COXI",
    "COX1",
    "Cytochrome c Oxidase subunit I", 
]

# =============================================================================

def read_species_list(file_path):
    """อ่านรายชื่อสปีชีส์จากไฟล์"""
    try:
        with open(file_path, "r", encoding='utf-8') as f:
            species_list = [line.strip() for line in f if line.strip()]
        return species_list
    except FileNotFoundError:
        print(f"ไม่พบไฟล์: {file_path}")
        return []

def search_sequences(species, max_sequences=None, search_terms=None):
    """ค้นหาซีเควนซ์สำหรับสปีชีส์หนึ่ง"""
    if search_terms is None:
        search_terms = SEARCH_TERMS
    
    all_ids = []
    
    for term in search_terms:
        search_query = f"{species}[Organism] AND {term}"
        try:
            handle = Entrez.esearch(
                db="nucleotide", 
                term=search_query, 
                retmax=max_sequences if max_sequences else 100
            )
            record = Entrez.read(handle)
            handle.close()
            
            ids = record["IdList"]
            all_ids.extend(ids)
            
            print(f"  - พบ {len(ids)} ซีเควนซ์จาก '{term}'")
            
            if max_sequences and len(all_ids) >= max_sequences:
                break
                
        except Exception as e:
            print(f"  - ข้อผิดพลาดในการค้นหา '{term}': {e}")
            continue
    
    # ลบซีเควนซ์ที่ซ้ำกัน
    unique_ids = list(dict.fromkeys(all_ids))
    
    # จำกัดจำนวนตามที่ต้องการ
    if max_sequences:
        unique_ids = unique_ids[:max_sequences]
    
    return unique_ids

def fetch_sequence_metadata(seq_id):
    """ดึงข้อมูล metadata ของซีเควนซ์หนึ่ง"""
    try:
        # ดึงข้อมูล GenBank
        handle = Entrez.efetch(db="nucleotide", id=seq_id, rettype="gb", retmode="text")
        genbank_record = SeqIO.read(handle, "genbank")
        handle.close()
        
        # ดึงข้อมูล FASTA
        handle = Entrez.efetch(db="nucleotide", id=seq_id, rettype="fasta", retmode="text")
        fasta_record = SeqIO.read(handle, "fasta")
        handle.close()
        
        # สร้าง metadata
        metadata = {
            'Accession': genbank_record.id,
            'Title': genbank_record.description,
            'Organism': '',
            'Length': len(genbank_record.seq),
            'Country': '',
            'Geo_location': '',
            'Source_info': '',
            'Collection_date': '',
            'Isolation_source': '',
            'Strain': '',
            'Authors': '',
            'Journal': ''
        }
        
        # ดึงข้อมูลจาก source feature
        for feature in genbank_record.features:
            if feature.type == "source":
                qualifiers = feature.qualifiers
                
                if 'organism' in qualifiers:
                    metadata['Organism'] = qualifiers['organism'][0]
                
                if 'country' in qualifiers:
                    metadata['Country'] = qualifiers['country'][0]
                
                if 'geo_loc_name' in qualifiers:
                    metadata['Geo_location'] = qualifiers['geo_loc_name'][0]
                
                # รวบรวมข้อมูล source
                source_parts = []
                for key in ['host', 'tissue_type', 'dev_stage']:
                    if key in qualifiers:
                        source_parts.append(f"{key.replace('_', ' ').title()}: {qualifiers[key][0]}")
                if 'environmental_sample' in qualifiers:
                    source_parts.append("Environmental sample")
                
                metadata['Source_info'] = "; ".join(source_parts)
                
                if 'collection_date' in qualifiers:
                    metadata['Collection_date'] = qualifiers['collection_date'][0]
                
                if 'isolation_source' in qualifiers:
                    metadata['Isolation_source'] = qualifiers['isolation_source'][0]
                
                if 'strain' in qualifiers:
                    metadata['Strain'] = qualifiers['strain'][0]
                elif 'isolate' in qualifiers:
                    metadata['Strain'] = qualifiers['isolate'][0]
                
                break
        
        # ดึงข้อมูล references
        if genbank_record.annotations.get('references'):
            ref = genbank_record.annotations['references'][0]
            metadata['Authors'] = ref.authors if ref.authors else ''
            metadata['Journal'] = ref.journal if ref.journal else ''
        
        return fasta_record, metadata
        
    except Exception as e:
        print(f"    - ข้อผิดพลาดในการดึงข้อมูล {seq_id}: {e}")
        return None, None

def main():
    """ฟังก์ชันหลัก"""
    print("=== NCBI Sequence Downloader for Primer Design ===")
    print(f"สปีชีส์หลัก: {TARGET_SPECIES}")
    print(f"จำนวนซีเควนซ์ต่อสปีชีส์เปรียบเทียบ: {COMPARISON_SEQUENCES_PER_SPECIES}")
    print("=" * 50)
    
    # อ่านรายชื่อสปีชีส์ทั้งหมด
    all_species = read_species_list(FISH_LIST_FILE)
    if not all_species:
        print("ไม่พบรายชื่อสปีชีส์")
        return
    
    # แยกสปีชีส์หลักและสปีชีส์เปรียบเทียบ
    comparison_species = [s for s in all_species if s not in TARGET_SPECIES]
    
    print(f"สปีชีส์ทั้งหมด: {len(all_species)}")
    print(f"สปีชีส์หลัก: {len(TARGET_SPECIES)}")
    print(f"สปีชีส์เปรียบเทียบ: {len(comparison_species)}")
    print()
    
    # เตรียม CSV headers
    csv_headers = [
        'Species', 'Sequence_Type', 'Accession', 'Title', 'Organism', 'Length', 
        'Country', 'Geo_location', 'Source_info', 'Collection_date', 
        'Isolation_source', 'Strain', 'Authors', 'Journal'
    ]
    
    metadata_list = []
    sequence_count = defaultdict(int)
    
    # เปิดไฟล์ FASTA
    with open(OUTPUT_FASTA, "w") as fasta_handle:
        
        # ประมวลผลสปีชีส์หลัก (ดึงทั้งหมด)
        for species in TARGET_SPECIES:
            print(f"\n🎯 ประมวลผลสปีชีส์หลัก: {species}")
            
            sequence_ids = search_sequences(species, max_sequences=None)
            
            if not sequence_ids:
                print(f"  ไม่พบซีเควนซ์สำหรับ {species}")
                continue
            
            print(f"  พบ {len(sequence_ids)} ซีเควนซ์ทั้งหมด")
            
            for i, seq_id in enumerate(sequence_ids, 1):
                print(f"  ดึงข้อมูลซีเควนซ์ที่ {i}/{len(sequence_ids)}: {seq_id}")
                
                fasta_record, metadata = fetch_sequence_metadata(seq_id)
                
                if fasta_record and metadata:
                    # เขียน FASTA
                    SeqIO.write(fasta_record, fasta_handle, "fasta")
                    
                    # เพิ่ม metadata
                    metadata['Species'] = species
                    metadata['Sequence_Type'] = 'Target'
                    metadata_list.append(metadata)
                    sequence_count[species] += 1
                    
                    print(f"    ✅ {metadata['Accession']} - {metadata['Length']:,} bp")
                else:
                    print(f"    ❌ ไม่สามารถดึงข้อมูลได้")
                
                time.sleep(0.1)
        
        # ประมวลผลสปีชีส์เปรียบเทียบ
        for species in comparison_species:
            print(f"\n📊 ประมวลผลสปีชีส์เปรียบเทียบ: {species}")
            
            sequence_ids = search_sequences(species, max_sequences=COMPARISON_SEQUENCES_PER_SPECIES)
            
            if not sequence_ids:
                print(f"  ไม่พบซีเควนซ์สำหรับ {species}")
                continue
            
            print(f"  จะดึง {len(sequence_ids)} ซีเควนซ์")
            
            for i, seq_id in enumerate(sequence_ids, 1):
                print(f"  ดึงข้อมูลซีเควนซ์ที่ {i}/{len(sequence_ids)}: {seq_id}")
                
                fasta_record, metadata = fetch_sequence_metadata(seq_id)
                
                if fasta_record and metadata:
                    # เขียน FASTA
                    SeqIO.write(fasta_record, fasta_handle, "fasta")
                    
                    # เพิ่ม metadata
                    metadata['Species'] = species
                    metadata['Sequence_Type'] = 'Comparison'
                    metadata_list.append(metadata)
                    sequence_count[species] += 1
                    
                    print(f"    ✅ {metadata['Accession']} - {metadata['Length']:,} bp")
                else:
                    print(f"    ❌ ไม่สามารถดึงข้อมูลได้")
                
                time.sleep(0.1)
    
    # เขียน metadata ลง CSV
    with open(OUTPUT_METADATA, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_headers)
        writer.writeheader()
        writer.writerows(metadata_list)
    
    # สรุปผลลัพธ์
    print("\n" + "=" * 50)
    print("🎉 เสร็จสิ้น!")
    print(f"📁 FASTA sequences: {OUTPUT_FASTA}")
    print(f"📊 Metadata: {OUTPUT_METADATA}")
    print(f"📈 จำนวนซีเควนซ์ทั้งหมด: {len(metadata_list)}")
    
    print(f"\n📋 สรุปตามสปีชีส์:")
    for species, count in sequence_count.items():
        species_type = "🎯 หลัก" if species in TARGET_SPECIES else "📊 เปรียบเทียบ"
        print(f"  {species_type} {species}: {count} ซีเควนซ์")
    
    # สรุปประเทศ
    countries = {}
    for metadata in metadata_list:
        if metadata['Country']:
            country = metadata['Country'].split(':')[0].strip()
            countries[country] = countries.get(country, 0) + 1
        elif metadata['Geo_location']:
            country = metadata['Geo_location'].split(':')[0].strip()
            countries[country] = countries.get(country, 0) + 1
    
    if countries:
        print(f"\n🌍 ประเทศที่พบ:")
        for country, count in sorted(countries.items()):
            print(f"  {country}: {count} ซีเควนซ์")

if __name__ == "__main__":
    main()
# Out:
# === NCBI Sequence Downloader for Primer Design ===
# สปีชีส์หลัก: ['oreochromis niloticus']
# จำนวนซีเควนซ์ต่อสปีชีส์เปรียบเทียบ: 3
# ==================================================
# สปีชีส์ทั้งหมด: 843
# สปีชีส์หลัก: 1
# สปีชีส์เปรียบเทียบ: 843
#
#
# 🎯 ประมวลผลสปีชีส์หลัก: oreochromis niloticus
#   - พบ 100 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 100 ซีเควนซ์จาก 'COX1'
#   - พบ 100 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   พบ 200 ซีเควนซ์ทั้งหมด
#   ดึงข้อมูลซีเควนซ์ที่ 1/200: 2814137097
#     ✅ PQ313152.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/200: 2814137095
#     ✅ PQ313151.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/200: 2814137093
#     ✅ PQ313150.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 4/200: 2814137091
#     ✅ PQ313149.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 5/200: 2814137089
#     ✅ PQ313148.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 6/200: 2814137087
#     ✅ PQ313147.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 7/200: 2814137085
#     ✅ PQ313146.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 8/200: 2814137083
#     ✅ PQ313145.1 - 335 bp
#   ดึงข้อมูลซีเควนซ์ที่ 9/200: 2797107365
#     ✅ PQ272509.1 - 653 bp
#   ดึงข้อมูลซีเควนซ์ที่ 10/200: 2797107363
#     ✅ PQ272508.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 11/200: 2797107361
#     ✅ PQ272507.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 12/200: 2797107359
#     ✅ PQ272506.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 13/200: 2797107357
#     ✅ PQ272505.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 14/200: 2797107355
#     ✅ PQ272504.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 15/200: 2797107289
#     ✅ PQ272471.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 16/200: 2662342309
#     ✅ PP217443.1 - 645 bp
#   ดึงข้อมูลซีเควนซ์ที่ 17/200: 2662342307
#     ✅ PP217442.1 - 690 bp
#   ดึงข้อมูลซีเควนซ์ที่ 18/200: 2668855049
#     ✅ OR148151.1 - 665 bp
#   ดึงข้อมูลซีเควนซ์ที่ 19/200: 281428845
#     ✅ NC_013663.1 - 16,627 bp
#   ดึงข้อมูลซีเควนซ์ที่ 20/200: 2385601740
#     ✅ OP947647.1 - 564 bp
#   ดึงข้อมูลซีเควนซ์ที่ 21/200: 2120156576
#     ✅ OK602736.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 22/200: 2120156572
#     ✅ OK602735.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 23/200: 2120156568
#     ✅ OK602734.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 24/200: 2120156564
#     ✅ OK602733.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 25/200: 2120156560
#     ✅ OK602732.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 26/200: 2120156556
#     ✅ OK602731.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 27/200: 2120156552
#     ✅ OK602730.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 28/200: 2120156550
#     ✅ OK602729.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 29/200: 2120156548
#     ✅ OK602728.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 30/200: 2120156544
#     ✅ OK602727.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 31/200: 2120156540
#     ✅ OK602726.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 32/200: 2120156534
#     ✅ OK602725.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 33/200: 2120156532
#     ✅ OK602724.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 34/200: 2120156530
#     ✅ OK602723.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 35/200: 2120156528
#     ✅ OK602722.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 36/200: 2120156524
#     ✅ OK602721.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 37/200: 2120156518
#     ✅ OK602720.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 38/200: 2120156516
#     ✅ OK602719.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 39/200: 2120156514
#     ✅ OK602718.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 40/200: 2120156512
#     ✅ OK602717.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 41/200: 2120156510
#     ✅ OK602716.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 42/200: 2120156508
#     ✅ OK602715.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 43/200: 2120156506
#     ✅ OK602714.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 44/200: 2120156504
#     ✅ OK602713.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 45/200: 2120156502
#     ✅ OK602712.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 46/200: 2120156500
#     ✅ OK602711.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 47/200: 2120156498
#     ✅ OK602710.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 48/200: 2120156496
#     ✅ OK602709.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 49/200: 2120156494
#     ✅ OK602708.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 50/200: 2120156491
#     ✅ OK602707.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 51/200: 2120156488
#     ✅ OK602706.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 52/200: 2120156485
#     ✅ OK602705.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 53/200: 2120156482
#     ✅ OK602704.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 54/200: 2120156479
#     ✅ OK602703.1 - 626 bp
#   ดึงข้อมูลซีเควนซ์ที่ 55/200: 2329467966
#     ✅ ON072403.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 56/200: 2329467962
#     ✅ ON072401.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 57/200: 2329467954
#     ✅ ON072397.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 58/200: 2329467950
#     ✅ ON072395.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 59/200: 2329467948
#     ✅ ON072394.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 60/200: 2329467872
#     ✅ ON072356.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 61/200: 2329467774
#     ✅ ON072307.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 62/200: 2329467726
#     ✅ ON072283.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 63/200: 2194009190
#     ✅ MW591125.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 64/200: 2194009188
#     ✅ MW591124.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 65/200: 2185074449
#     ✅ MN869888.1 - 642 bp
#   ดึงข้อมูลซีเควนซ์ที่ 66/200: 2185074447
#     ✅ MN869887.1 - 642 bp
#   ดึงข้อมูลซีเควนซ์ที่ 67/200: 1569726465
#     ✅ MG714814.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 68/200: 1569726463
#     ✅ MG714813.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 69/200: 1569726461
#     ✅ MG714812.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 70/200: 1569726459
#     ✅ MG714811.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 71/200: 1569726457
#     ✅ MG714810.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 72/200: 1569726455
#     ✅ MG714809.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 73/200: 1569726453
#     ✅ MG714808.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 74/200: 1569726451
#     ✅ MG714807.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 75/200: 1569726449
#     ✅ MG714806.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 76/200: 1569726447
#     ✅ MG714805.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 77/200: 1569726445
#     ✅ MG714804.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 78/200: 1569726443
#     ✅ MG714803.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 79/200: 1569726441
#     ✅ MG714802.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 80/200: 1569726439
#     ✅ MG714801.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 81/200: 1569726437
#     ✅ MG714800.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 82/200: 1569726435
#     ✅ MG714799.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 83/200: 1569726433
#     ✅ MG714798.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 84/200: 1569726431
#     ✅ MG714797.1 - 650 bp
#   ดึงข้อมูลซีเควนซ์ที่ 85/200: 2119874634
#     ✅ MW027194.1 - 495 bp
#   ดึงข้อมูลซีเควนซ์ที่ 86/200: 2119874586
#     ✅ MW027170.1 - 447 bp
#   ดึงข้อมูลซีเควนซ์ที่ 87/200: 2119874566
#     ✅ MW027160.1 - 695 bp
#   ดึงข้อมูลซีเควนซ์ที่ 88/200: 2067502799
#     ✅ MT884660.1 - 603 bp
#   ดึงข้อมูลซีเควนซ์ที่ 89/200: 2067502797
#     ✅ MT884659.1 - 603 bp
#   ดึงข้อมูลซีเควนซ์ที่ 90/200: 2067502795
#     ✅ MT884658.1 - 603 bp
#   ดึงข้อมูลซีเควนซ์ที่ 91/200: 1829760421
#     ✅ MK497155.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 92/200: 1829760417
#     ✅ MK497153.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 93/200: 1829760415
#     ✅ MK497152.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 94/200: 1829760413
#     ✅ MK497151.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 95/200: 1829760411
#     ✅ MK497150.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 96/200: 1829760409
#     ✅ MK497149.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 97/200: 1829760407
#     ✅ MK497148.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 98/200: 1829760405
#     ✅ MK497147.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 99/200: 1829760403
#     ✅ MK497146.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 100/200: 1829760401
#     ✅ MK497145.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 101/200: 2957191119
#     ✅ PV523648.1 - 700 bp
#   ดึงข้อมูลซีเควนซ์ที่ 102/200: 2920260992
#     ✅ PV202833.1 - 645 bp
#   ดึงข้อมูลซีเควนซ์ที่ 103/200: 2912172103
#     ✅ PV113437.1 - 633 bp
#   ดึงข้อมูลซีเควนซ์ที่ 104/200: 2912149114
#     ✅ PV113171.1 - 633 bp
#   ดึงข้อมูลซีเควนซ์ที่ 105/200: 2308605813
#     ✅ OP518681.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 106/200: 2308605811
#     ✅ OP518680.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 107/200: 2308605809
#     ✅ OP518679.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 108/200: 2308605806
#     ✅ OP518678.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 109/200: 2308605804
#     ✅ OP518677.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 110/200: 2308605802
#     ✅ OP518676.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 111/200: 2308605799
#     ✅ OP518675.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 112/200: 2308605797
#     ✅ OP518674.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 113/200: 2308605795
#     ✅ OP518673.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 114/200: 2308605792
#     ✅ OP518672.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 115/200: 2308605790
#     ✅ OP518671.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 116/200: 2308605788
#     ✅ OP518670.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 117/200: 2308605786
#     ✅ OP518669.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 118/200: 2308605784
#     ✅ OP518668.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 119/200: 2308605782
#     ✅ OP518667.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 120/200: 2308605780
#     ✅ OP518666.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 121/200: 2308605777
#     ✅ OP518665.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 122/200: 2308605775
#     ✅ OP518664.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 123/200: 2308605772
#     ✅ OP518663.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 124/200: 2308605770
#     ✅ OP518662.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 125/200: 2308605768
#     ✅ OP518661.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 126/200: 2308605766
#     ✅ OP518660.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 127/200: 2308605764
#     ✅ OP518659.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 128/200: 2308605762
#     ✅ OP518658.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 129/200: 2308605760
#     ✅ OP518657.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 130/200: 2308605758
#     ✅ OP518656.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 131/200: 2308605756
#     ✅ OP518655.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 132/200: 2308605754
#     ✅ OP518654.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 133/200: 2308605752
#     ✅ OP518653.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 134/200: 2308605750
#     ✅ OP518652.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 135/200: 2308605748
#     ✅ OP518651.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 136/200: 2308605746
#     ✅ OP518650.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 137/200: 2308605744
#     ✅ OP518649.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 138/200: 2308605742
#     ✅ OP518648.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 139/200: 2308605740
#     ✅ OP518647.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 140/200: 2308605738
#     ✅ OP518646.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 141/200: 2308605736
#     ✅ OP518645.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 142/200: 2308605734
#     ✅ OP518644.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 143/200: 2308605732
#     ✅ OP518643.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 144/200: 2308605730
#     ✅ OP518642.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 145/200: 2308605728
#     ✅ OP518641.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 146/200: 2308605726
#     ✅ OP518640.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 147/200: 2308605724
#     ✅ OP518639.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 148/200: 2308605722
#     ✅ OP518638.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 149/200: 2308605720
#     ✅ OP518637.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 150/200: 2308605718
#     ✅ OP518636.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 151/200: 2308605716
#     ✅ OP518635.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 152/200: 2308605714
#     ✅ OP518634.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 153/200: 2308605712
#     ✅ OP518633.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 154/200: 2308605710
#     ✅ OP518632.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 155/200: 2308605708
#     ✅ OP518631.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 156/200: 2308605706
#     ✅ OP518630.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 157/200: 2308605704
#     ✅ OP518629.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 158/200: 2308605702
#     ✅ OP518628.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 159/200: 2308605700
#     ✅ OP518627.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 160/200: 2308605698
#     ✅ OP518626.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 161/200: 2308605696
#     ✅ OP518625.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 162/200: 2308605694
#     ✅ OP518624.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 163/200: 2308605692
#     ✅ OP518623.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 164/200: 2308605690
#     ✅ OP518622.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 165/200: 2308605688
#     ✅ OP518621.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 166/200: 2308605686
#     ✅ OP518620.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 167/200: 2308605684
#     ✅ OP518619.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 168/200: 2308605682
#     ✅ OP518618.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 169/200: 2308605680
#     ✅ OP518617.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 170/200: 2308605678
#     ✅ OP518616.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 171/200: 2308605676
#     ✅ OP518615.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 172/200: 2308605674
#     ✅ OP518614.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 173/200: 2308605672
#     ✅ OP518613.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 174/200: 2308605670
#     ✅ OP518612.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 175/200: 2308605668
#     ✅ OP518611.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 176/200: 2308605666
#     ✅ OP518610.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 177/200: 2308605663
#     ✅ OP518609.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 178/200: 2308605661
#     ✅ OP518608.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 179/200: 2308605659
#     ✅ OP518607.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 180/200: 2308605657
#     ✅ OP518606.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 181/200: 2308605655
#     ✅ OP518605.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 182/200: 2308605653
#     ✅ OP518604.1 - 613 bp
#   ดึงข้อมูลซีเควนซ์ที่ 183/200: 2875056139
#     ✅ PQ821106.1 - 156 bp
#   ดึงข้อมูลซีเควนซ์ที่ 184/200: 2874285198
#     ✅ PQ814801.1 - 155 bp
#   ดึงข้อมูลซีเควนซ์ที่ 185/200: 2874279545
#     ✅ PQ814753.1 - 152 bp
#   ดึงข้อมูลซีเควนซ์ที่ 186/200: 2873717126
#     ✅ PQ810734.1 - 155 bp
#   ดึงข้อมูลซีเควนซ์ที่ 187/200: 2873662775
#     ✅ PQ810007.1 - 155 bp
#   ดึงข้อมูลซีเควนซ์ที่ 188/200: 2645815005
#     ✅ PP094733.1 - 646 bp
#   ดึงข้อมูลซีเควนซ์ที่ 189/200: 2645815001
#     ✅ PP094729.1 - 630 bp
#   ดึงข้อมูลซีเควนซ์ที่ 190/200: 2645814999
#     ✅ PP094730.1 - 657 bp
#   ดึงข้อมูลซีเควนซ์ที่ 191/200: 2131608137
#     ✅ OL441031.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 192/200: 2131608133
#     ✅ OL441029.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 193/200: 2131608130
#     ✅ OL441028.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 194/200: 2131608128
#     ✅ OL441027.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 195/200: 2131608125
#     ✅ OL441026.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 196/200: 2131608123
#     ✅ OL441025.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 197/200: 2131608118
#     ✅ OL441023.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 198/200: 2131608115
#     ✅ OL441022.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 199/200: 2131608113
#     ✅ OL441021.1 - 378 bp
#   ดึงข้อมูลซีเควนซ์ที่ 200/200: 2131608111
#     ✅ OL441020.1 - 378 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Sarotherodon melanotheron
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2989752492
#     ✅ PQ628716.1 - 616 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2989752490
#     ✅ PQ628715.1 - 662 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2989752488
#     ✅ PQ628714.1 - 662 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Amatitlania nigrofasciata
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2642374931
#     ✅ OQ991956.1 - 515 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2642374929
#     ✅ OQ991955.1 - 512 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1519156081
#     ✅ MG496071.1 - 648 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Coptodon rendalli
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2892915884
#     ✅ KU193980.2 - 656 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 343223256
#     ✅ JN312270.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 343223254
#     ✅ JN312269.1 - 652 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Coptodon zillii
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2642376528
#     ✅ OQ992029.1 - 518 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2642376526
#     ✅ OQ992028.1 - 518 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2642376524
#     ✅ OQ992027.1 - 538 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Etroplus maculatus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 
1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2662342280
#     ✅ PP217420.1 - 683 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2662342278
#     ✅ PP217419.1 - 639 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Catlocarpio siamensis
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1088475395
#     ✅ NC_031523.1 - 16,549 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1074196591
#     ✅ AP011184.1 - 16,549 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 310788803
#     ✅ HM536911.1 - 685 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cirrhinus cirrhosus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2897969101
#     ✅ LC823281.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2668854853
#     ✅ OR148061.1 - 664 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1150150371
#     ✅ NC_033964.1 - 16,588 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cirrhinus jullieni
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Cirrhinus jullieni
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cirrhinus microlepis
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1088482447
#     ✅ NC_031608.1 - 16,578 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1784555821
#     ✅ MK902690.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1591634319
#     ✅ MK116354.1 - 529 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cirrhinus mrigala
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2728418104
#     ✅ OP289478.1 - 16,593 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2662304169
#     ✅ PP217304.1 - 599 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2668854861
#     ✅ OR148065.1 - 657 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cirrhinus prosemion
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Cirrhinus prosemion
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Ctenopharyngodon idella
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2587722385
#     ✅ OP575587.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2293035677
#     ✅ MZ870709.1 - 585 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2253756093
#     ✅ ON097891.1 - 655 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cyclocheilichthys apogon
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1088478058
#     ✅ NC_031554.1 - 16,586 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2194009030
#     ✅ MW591045.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2194009028
#     ✅ MW591044.1 - 655 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cyclocheilichthys armatus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1634554324
#     ✅ MK628330.1 - 630 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1634554038
#     ✅ MK049385.1 - 648 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1634554036
#     ✅ MK049384.1 - 648 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cyclocheilichthys enoplos
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 570700223
#     ✅ NC_023231.1 - 16,579 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1591634279
#     ✅ MK116334.1 - 529 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1607272150
#     ✅ MK448148.1 - 630 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cyclocheilichthys lagleri
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Cyclocheilichthys lagleri
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cyclocheilichthys repasson
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 952544053
#     ✅ KT001064.1 - 687 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 952543973
#     ✅ KT001024.1 - 594 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 375085111
#     ✅ JQ346165.1 - 646 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cyprinus carpio
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2662304236
#     ✅ PP217341.1 - 689 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2198157993
#     ✅ MT119090.1 - 681 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2198157992
#     ✅ MT119089.1 - 681 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Cyprinus rubrofuscus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1376175950
#     ✅ MF805659.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1376175948
#     ✅ MF805658.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1376175946
#     ✅ MF805657.1 - 651 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Danio albolineatus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2053535956
#     ✅ MN342400.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2053535954
#     ✅ MN342399.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2053535952
#     ✅ MN342398.1 - 651 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Danio choprae
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2053535982
#     ✅ MN342413.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2053535980
#     ✅ MN342412.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2053535978
#     ✅ MN342411.1 - 651 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Danio kerri
#   - พบ 1 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 1 ซีเควนซ์จาก 'COX1'
#   - พบ 1 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   จะดึง 2 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/2: 353078349
#     ✅ JF915570.1 - 693 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/2: 299832327
#     ✅ HM224147.1 - 658 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Danio margaritatus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 959122871
#     ✅ NC_028526.1 - 16,620 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2053536036
#     ✅ MN342440.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2053536034
#     ✅ MN342439.1 - 651 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Danio rerio
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2897969103
#     ✅ LC823282.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2751572929
#     ✅ PP963510.1 - 16,596 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 15079186
#     ✅ NC_002333.2 - 16,596 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Discherodontus parvus
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Discherodontus parvus
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Epalzeorhynchos bicolor
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1088476480
#     ✅ NC_031534.1 - 16,465 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2053536323
#     ✅ MN342578.1 - 651 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2053536321
#     ✅ MN342577.1 - 651 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Epalzeorhynchos frenatum
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1150150341
#     ✅ NC_033962.1 - 16,457 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1139378031
#     ✅ AP012147.1 - 16,457 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2053536327
#     ✅ MN342580.1 - 651 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Epalzeorhynchos munense
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Epalzeorhynchos munense
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Hampala macrolepidota
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2
bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mekongina erythrospila
#   - พบ 2 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   จะดึง 2 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/2: 1591634321
#     ✅ MK116355.1 - 529 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/2: 570462543
#     ✅ KC631201.1 - 643 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mekongina lancangensis
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Mekongina lancangensis
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mekongina hoops
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Mekongina hoops
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mekongina baramensis
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Mekongina baramensis
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Pangasius bocourti
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 966344204
#     ✅ KT289884.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 966344202
#     ✅ KT289883.1 - 652 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1783127953
#     ✅ MN073456.1 - 609 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Pangasius conchophilus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 966344208
#     ✅ KT289886.1 - 656 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 966344206
#     ✅ KT289885.1 - 656 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1607272204
#     ✅ MK448175.1 - 621 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Pangasius hypophthalmus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2185074460
#     ✅ MN869892.1 - 658 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2185074457
#     ✅ MN869891.1 - 658 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2185074455
#     ✅ MN869890.1 - 641 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Pangasius krempfi
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 966344190
#     ✅ KT289877.1 - 656 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1751379139
#     ✅ MK777723.1 - 524 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1783127961
#     ✅ MN073460.1 - 625 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Pangasius sanitwongsei
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1495895050
#     ✅ MG981065.1 - 551 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1253240716
#     ✅ MG076884.1 - 535 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1108491513
#     ✅ KU568952.1 - 644 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Hemibagrus filamentus
#   - พบ 1 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 1 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   จะดึง 1 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/1: 375333340
#     ✅ JQ289147.1 - 568 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Hemibagrus nemurus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2643562610
#     ✅ PP065776.1 - 563 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1779818173
#     ✅ MN605516.1 - 657 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1820088751
#     ✅ MN243488.1 - 680 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Hemibagrus spilopterus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1634554178
#     ✅ MK049455.1 - 630 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1495895080
#     ✅ MG981080.1 - 551 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1253240731
#     ✅ MG076899.1 - 530 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Hemibagrus wyckii
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1495895084
#     ✅ MG981082.1 - 551 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1253240733
#     ✅ MG076901.1 - 531 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 378947658
#     ✅ JF781179.1 - 582 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus cavasius
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2897969071
#     ✅ LC823266.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2897969059
#     ✅ LC823260.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 2587722441
#     ✅ OP575615.1 - 652 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus gulio
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2897969245
#     ✅ LC823353.1 - 655 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1826603097
#     ✅ MN458398.1 - 642 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1044898252
#     ✅ KX455905.1 - 696 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus mysticetus
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1751379133
#     ✅ MK777720.1 - 580 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1607272234
#     ✅ MK448190.1 - 630 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1607272216
#     ✅ MK448181.1 - 630 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus nigriceps
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 1495895076
#     ✅ MG981078.1 - 551 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 1253240729
#     ✅ MG076897.1 - 539 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1018444502
#     ✅ KU692658.1 - 652 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus pluriradiatus
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Mystus pluriradiatus
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus pulcher
#   - พบ 0 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 0 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   ไม่พบซีเควนซ์สำหรับ Mystus pulcher
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus singaringan
#   - พบ 3 ซีเควนซ์จาก 'COI'
#   จะดึง 3 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/3: 2073950688
#     ✅ MN992971.1 - 633 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2/3: 2073950686
#     ✅ MN992970.1 - 573 bp
#   ดึงข้อมูลซีเควนซ์ที่ 3/3: 1634554180
#     ✅ MK049456.1 - 636 bp
#
# 📊 ประมวลผลสปีชีส์เปรียบเทียบ: Mystus wolffii
#   - พบ 2 ซีเควนซ์จาก 'COI'
#   - พบ 0 ซีเควนซ์จาก 'COXI'
#   - พบ 0 ซีเควนซ์จาก 'COX1'
#   - พบ 2 ซีเควนซ์จาก 'Cytochrome c Oxidase subunit I'
#   จะดึง 2 ซีเควนซ์
#   ดึงข้อมูลซีเควนซ์ที่ 1/2: 1820088741
#     ✅ MN243483.1 - 680 bp
#   ดึงข้อมูลซีเควนซ์ที่ 2
 3 ซีเควนซ์
#   📊 เปรียบเทียบ Gerres abbreviatus: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Gerres filamentosus: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Gerres limbatus: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Gerres longirostris: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Gerres macracanthus: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Gerres oyena: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Pentaprion longimanus: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Ulaema lefroyi: 2 ซีเควนซ์
#   📊 เปรียบเทียบ Chelon planiceps: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Chelon subviridis: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Ellochelon vaigiensis: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Liza carinata: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Liza melinoptera: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Liza subviridis: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Moolgarda cunnesius: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Moolgarda seheli: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Mugil cephalus: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Valamugil buchanani: 3 ซีเควนซ์
#   📊 เปรียบเทียบ Valamugil georgii: 1 ซีเควนซ์
#   📊 เปรียบเทียบ Valamugil speigleri: 1 ซีเควนซ์
#
# 🌍 ประเทศที่พบ:
#   Australia: 16 ซีเควนซ์
#   Austria: 4 ซีเควนซ์
#   Baltic Sea: 3 ซีเควนซ์
#   Bangladesh: 89 ซีเควนซ์
#   Brazil: 29 ซีเควนซ์
#   Brunei: 2 ซีเควนซ์
#   Cambodia: 7 ซีเควนซ์
#   China: 70 ซีเควนซ์
#   Democratic Republic of the Congo: 4 ซีเควนซ์
#   Egypt: 13 ซีเควนซ์
#   French Polynesia: 6 ซีเควนซ์
#   Georgia: 3 ซีเควนซ์
#   Germany: 3 ซีเควนซ์
#   Ghana: 2 ซีเควนซ์
#   Greece: 8 ซีเควนซ์
#   Guatemala: 3 ซีเควนซ์
#   Guinea-Bissau: 4 ซีเควนซ์
#   India: 174 ซีเควนซ์
#   Indonesia: 118 ซีเควนซ์
#   Iran: 3 ซีเควนซ์
#   Israel: 14 ซีเควนซ์
#   Japan: 11 ซีเควนซ์
#   Laos: 10 ซีเควนซ์
#   Lebanon: 1 ซีเควนซ์
#   Madagascar: 4 ซีเควนซ์
#   Malaysia: 110 ซีเควนซ์
#   Mauritius: 1 ซีเควนซ์
#   Mayotte: 3 ซีเควนซ์
#   Mediterranean Sea: 1 ซีเควนซ์
#   Mexico: 17 ซีเควนซ์
#   Micronesia, Federated States of: 4 ซีเควนซ์
#   Myanmar: 5 ซีเควนซ์
#   Namibia: 2 ซีเควนซ์
#   Nepal: 3 ซีเควนซ์
#   Nicaragua: 1 ซีเควนซ์
#   Nigeria: 21 ซีเควนซ์
#   Norway: 1 ซีเควนซ์
#   Pacific Ocean: 9 ซีเควนซ์
#   Pakistan: 17 ซีเควนซ์
#   Peru: 2 ซีเควนซ์
#   Philippines: 57 ซีเควนซ์
#   Qatar: 1 ซีเควนซ์
#   Russia: 6 ซีเควนซ์
#   Saudi Arabia: 9 ซีเควนซ์
#   Seychelles: 1 ซีเควนซ์
#   Singapore: 3 ซีเควนซ์
#   South Africa: 25 ซีเควนซ์
#   Spain: 2 ซีเควนซ์
#   Sri Lanka: 3 ซีเควนซ์
#   Suriname: 1 ซีเควนซ์
#   Taiwan: 9 ซีเควนซ์
#   Tanzania: 132 ซีเควนซ์
#   Thailand: 126 ซีเควนซ์
#   Turkey: 3 ซีเควนซ์
#   Turkmenistan: 2 ซีเควนซ์
#   USA: 5 ซีเควนซ์
#   Vanuatu: 2 ซีเควนซ์
#   Viet Nam: 35 ซีเควนซ์
#   Wallis and Futuna: 1 ซีเควนซ์
